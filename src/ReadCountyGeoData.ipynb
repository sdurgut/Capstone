# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %% [markdown]
# ## County data from wikipedia

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/User:Michael_J/County_table', header=0, parse_dates=False)
df[0].to_csv("ConuntyData.csv")

# %%
# Out:
#       Sort [1] State   FIPS   County [2] County Seat(s) [3]  \
# 0            1    AL   1001      Autauga         Prattville
# 1            2    AL   1003      Baldwin        Bay Minette
# 2            3    AL   1005      Barbour            Clayton
# 3            4    AL   1007         Bibb        Centreville
# 4            5    AL   1009       Blount            Oneonta
# 5            6    AL   1011      Bullock      Union Springs
# 6            7    AL   1013       Butler         Greenville
# 7            8    AL   1015      Calhoun           Anniston
# 8            9    AL   1017     Chambers          Lafayette
# 9           10    AL   1019     Cherokee             Centre
# 10          11    AL   1021      Chilton            Clanton
# 11          12    AL   1023      Choctaw             Butler
# 12          13    AL   1025       Clarke         Grove Hill
# 13          14    AL   1027         Clay            Ashland
# 14          15    AL   1029     Cleburne             Heflin
# ...
